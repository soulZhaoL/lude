# %%
import warnings
warnings.filterwarnings('ignore') # 忽略警告
import pandas as pd
from pandas import IndexSlice as idx
pd.set_option('display.max_columns', None)  # 当列太多时不换行
df = pd.read_pickle('cb_data.pkl') # 导入转债数据
index = pd.read_pickle('index.pkl') # 导入指数数据

# %%
# 基础设置
start_date = '20220801' # 开始日期
end_date = '20230707' # 结束日期
hold_num = 10 # 持有数量
SP = 0.06 # 盘中止盈条件
c_rate =  1 / 10000 # 买卖一次花费的总佣金和滑点（双边）
benchmark = 'index_jsl' # 选择基准，集思录等权:index_jsl, 沪深300:index_300, 中证1000:index_1000, 国证2000:index_2000

# %%
# 排除设置
df = df[(df.index.get_level_values('trade_date') >= start_date) & (df.index.get_level_values('trade_date') <= end_date)] # 选择时间范围内数据
df['filter'] = False # 初始化过滤器
df.loc[df.is_call.isin(['已公告强赎', '公告到期赎回','公告实施强赎', '公告提示强赎', '已满足强赎条件']), 'filter'] = True # 排除赎回状态
df.loc[df.close > 150, 'filter'] = True # 排除收盘价大于150的标的
df.loc[df.close < 100, 'filter'] = True # 排除收盘价小于100的标的
df.loc[df.list_days <= 3, 'filter'] = True # 排除新债

# %%
# 计算三低值
df['SDZ']=(df.loc[df['filter'] == False,'close'] *(1+df.loc[df['filter'] == False,'conv_prem'])  * df.loc[df['filter'] == False,'remain_size'])
df['rank'] = df.groupby('trade_date')['SDZ'].rank('first', ascending=True) # 按总分从高到低计算排名

# %%
code_group = df.groupby('code')
# (2)次日止盈条件
df['aft_open'] = code_group.open.shift(-1) # 计算次日开盘价
df['aft_close'] = code_group.close.shift(-1) # 计算次日收盘价
df['aft_high'] = code_group.high.shift(-1) # 计算次日最高价
df['time_return']= code_group.pct_chg.shift(-1) # 先计算不止盈情况的收益率
df['SFZY']='未满足止盈' #先记录默认情况
pd.set_option('display.max_columns', None)  # 当列太多时不换行

# %%
df.loc[df['aft_high'] >= df['close'] * (1+SP),'time_return'] = SP # 满足止盈条件止盈
df.loc[df['aft_open'] >= df['close'] * (1+SP),'time_return'] = \
(df['aft_open']-df['close'])/df['close'] # 开盘满足止盈条件则按开盘价计算涨幅
df.loc[df['aft_high'] >= df['close'] * (1+SP),'SFZY'] = '满足止盈'

# %%
# 计算每日信号 采样信号 持仓状态
df.loc[(df['rank'] <= hold_num), 'signal'] = 1 # 标记信号
df.dropna(subset=['signal'], inplace=True) # 删除没有标记的行
df.sort_values(by='trade_date', inplace=True) # 按日期排序

# %%
# 计算组合回报
res = pd.DataFrame()
res['time_return'] = df.groupby('trade_date')['time_return'].mean() # 按等权计算组合回报
pd.set_option('display.max_rows',None)
# 计算手续费
pos_df = df['signal'].unstack('code')
pos_df.fillna(0, inplace=True)
res['cost'] = pos_df.diff().abs().sum(axis=1) * c_rate / (pos_df.shift().sum(axis=1) + pos_df.sum(axis=1))
res.iloc[0, 1] = 0.5 * c_rate# 修正首行手续费
res['time_return'] = (res['time_return'] + 1) * (1 - res['cost']) - 1# 扣除手续费及佣金后的回报

# %%
# 用quantstats生成评价报告
import quantstats as qs
qs.reports.full(res.time_return, benchmark=index[benchmark])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2022-08-01  2022-08-01
# End Period                 2023-07-07  2023-07-07
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          19.4%       -4.44%
# CAGR﹪                     20.97%      -4.76%
#
# Sharpe                     1.46        -0.45
# Prob. Sharpe Ratio         91.43%      33.36%
# Smart Sharpe               1.2         -0.37
# Sortino                    2.18        -0.6
# Smart Sortino              1.79        -0.49
# Sortino/√2                 1.54        -0.42
# Smart Sortino/√2           1.27        -0.35
# Omega                      1.27        1.27
#
# Max Drawdown               -10.39%     -12.12%
# Longest DD Days            148         323
# Volatility (ann.)          14.21%      10.05%
# R^2                        0.06        0.06
# Information Ratio          0.1         0.1
# Calmar                     2.02        -0.39
# Skew                       -0.21       -0.41
# Kurtosis                   0.43        0.5
#
# Expected Daily %           0.08%       -0.02%
# Expected Monthly %         1.49%       -0.38%
# Expected Yearly %          9.27%       -2.24%
# Kelly Criterion            0.66%       -3.17%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.39%      -1.06%
# Expected Shortfall (cVaR)  -1.39%      -1.06%
#
# Max Consecutive Wins       6           8
# Max Consecutive Losses     11          7
# Gain/Pain Ratio            0.27        -0.07
# Gain/Pain (1M)             1.62        -0.25
#
# Payoff Ratio               0.93        0.91
# Profit Factor              1.27        0.93
# Common Sense Ratio         1.28        0.8
# CPC Index                  0.61        0.43
# Tail Ratio                 1.0         0.86
# Outlier Win Ratio          2.24        3.54
# Outlier Loss Ratio         3.15        3.84
#
# MTD                        1.38%       0.31%
# 3M                         8.95%       -0.92%
# 6M                         16.97%      3.1%
# YTD                        19.94%      6.11%
# 1Y                         19.4%       -4.44%
# 3Y (ann.)                  20.97%      -4.76%
# 5Y (ann.)                  20.97%      -4.76%
# 10Y (ann.)                 20.97%      -4.76%
# All-time (ann.)            20.97%      -4.76%
#
# Best Day                   2.17%       1.56%
# Worst Day                  -2.65%      -2.22%
# Best Month                 9.06%       6.15%
# Worst Month                -6.46%      -6.02%
# Best Year                  19.94%      6.11%
# Worst Year                 -0.44%      -9.94%
#
# Avg. Drawdown              -1.51%      -4.65%
# Avg. Drawdown Days         16          112
# Recovery Factor            1.87        -0.37
# Ulcer Index                0.03        0.07
# Serenity Index             0.8         -0.04
#
# Avg. Up Month              4.83%       2.04%
# Avg. Down Month            -2.92%      -2.67%
# Win Days %                 52.21%      50.88%
# Win Month %                66.67%      50.0%
# Win Quarter %              80.0%       40.0%
# Win Year %                 50.0%       50.0%
#
# Beta                       0.34        -
# Alpha                      0.22        -
# Correlation                23.91%      -
# Treynor Ratio              57.39%      -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  
#                      yy_rating orgform area industry_1 industry_2 industry_3  \
# code      trade_date
# 123014.SZ 2023-01-20         8    民营企业   天津       电气设备      输变电设备     电气自控设备
# 123052.SZ 2023-01-20        8-    民营企业   湖南       基础化工       化学制品       涂料涂漆
# 123080.SZ 2023-01-20         8    民营企业   湖北         建筑       基础建设       路桥建设
# 113561.SH 2023-01-20              民营企业   浙江       交运设备         汽车      汽车零部件
# 128079.SZ 2023-01-20              民营企业   广东       轻工制造       造纸印刷       包装印刷
# 113566.SH 2023-01-20              民营企业   上海       轻工制造       造纸印刷       包装印刷
# 113567.SH 2023-01-20              民营企业   浙江       机械设备       通用设备     其他通用机械
# 128036.SZ 2023-01-20        8+    民营企业   广东       农林牧渔        畜牧业         饲料
# 123140.SZ 2023-01-20              民营企业   浙江       信息技术      计算机硬件    专用计算机设备
# 113646.SH 2023-01-20              民营企业   贵州       轻工制造       造纸印刷       包装印刷
#
#                       popularity_ranking  theory_conv_prem  mod_conv_prem  \
# code      trade_date
# 123014.SZ 2023-01-20                 271          0.276094       0.099146
# 123052.SZ 2023-01-20                 310          0.189154       0.049964
# 123080.SZ 2023-01-20                 112          0.115134       0.052082
# 113561.SH 2023-01-20                 290          0.357400       0.036444
# 128079.SZ 2023-01-20                  37          0.157288       0.086014
# 113566.SH 2023-01-20                 421          0.384801       0.022225
# 113567.SH 2023-01-20                   0          0.117187      -0.020037
# 128036.SZ 2023-01-20                 213          0.415094       0.141654
# 123140.SZ 2023-01-20                 107          0.234231       0.070505
# 113646.SH 2023-01-20                 101          0.371684       0.171496
#
#                       filter         SDZ  rank  aft_open  aft_close  aft_high  \
# code      trade_date
# 123014.SZ 2023-01-20   False  214.250645   1.0   134.600    134.966   135.149
# 123052.SZ 2023-01-20   False  254.300076   2.0   136.671    137.376   137.550
# 123080.SZ 2023-01-20   False  256.958454   3.0   148.096    148.410   150.690
# 113561.SH 2023-01-20   False  259.414963   4.0   125.161    125.316   125.870
# 128079.SZ 2023-01-20   False  272.559687   5.0   145.900    147.168   147.738
# 113566.SH 2023-01-20   False  276.585358   6.0   121.876    123.889   124.890
# 113567.SH 2023-01-20   False  293.429677   7.0   138.902    137.860   140.140
# 128036.SZ 2023-01-20   False  296.825000   8.0   131.460    132.000   132.005
# 123140.SZ 2023-01-20   False  301.752181   9.0   134.899    134.837   135.629
# 113646.SH 2023-01-20   False  304.793760  10.0   135.860    136.256   136.447
#
#                       time_return   SFZY  signal
# code      trade_date
# 123014.SZ 2023-01-20     0.005184  未满足止盈     1.0
# 123052.SZ 2023-01-20     0.006322  未满足止盈     1.0
# 123080.SZ 2023-01-20     0.004127  未满足止盈     1.0
# 113561.SH 2023-01-20     0.009302  未满足止盈     1.0
# 128079.SZ 2023-01-20     0.017921  未满足止盈     1.0
# 113566.SH 2023-01-20     0.016400  未满足止盈     1.0
# 113567.SH 2023-01-20    -0.003073  未满足止盈     1.0
# 128036.SZ 2023-01-20     0.008018  未满足止盈     1.0
# 123140.SZ 2023-01-20     0.002520  未满足止盈     1.0
# 113646.SH 2023-01-20     0.005884  未满足止盈     1.0
